# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
# %pip install hvplot --user
# %pip install geoviews --user
# %pip install geopandas --user
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# Requirement already satisfied: hvplot in c:\users\meetp\appdata\roaming\python\python39\site-packages (0.8.4)
# Requirement already satisfied: bokeh>=1.0.0 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from hvplot) (3.2.2)
# Requirement already satisfied: colorcet>=2 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from hvplot) (3.0.1)
# Requirement already satisfied: holoviews>=1.11.0 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from hvplot) (1.17.1)
# Requirement already satisfied: pandas in c:\python39\lib\site-packages (from hvplot) (1.5.3)
# Requirement already satisfied: numpy>=1.15 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from hvplot) (1.23.5)
# Requirement already satisfied: packaging in c:\users\meetp\appdata\roaming\python\python39\site-packages (from hvplot) (23.1)
# Requirement already satisfied: panel>=0.11.0 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from hvplot) (1.2.3)
# Requirement already satisfied: param>=1.9.0 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from hvplot) (1.13.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from bokeh>=1.0.0->hvplot) (3.1.2)
# Requirement already satisfied: contourpy>=1 in c:\python39\lib\site-packages (from bokeh>=1.0.0->hvplot) (1.0.7)
# Requirement already satisfied: pillow>=7.1.0 in c:\python39\lib\site-packages (from bokeh>=1.0.0->hvplot) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from bokeh>=1.0.0->hvplot) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from bokeh>=1.0.0->hvplot) (6.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\python39\lib\site-packages (from bokeh>=1.0.0->hvplot) (2023.10.0)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from colorcet>=2->hvplot) (0.5.0)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from holoviews>=1.11.0->hvplot) (3.0.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from pandas->hvplot) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python39\lib\site-packages (from pandas->hvplot) (2022.7.1)
# Requirement already satisfied: markdown in c:\users\meetp\appdata\roaming\python\python39\site-packages (from panel>=0.11.0->hvplot) (3.4.3)
# Requirement already satisfied: markdown-it-py in c:\users\meetp\appdata\roaming\python\python39\site-packages (from panel>=0.11.0->hvplot) (3.0.0)
# Requirement already satisfied: linkify-it-py in c:\users\meetp\appdata\roaming\python\python39\site-packages (from panel>=0.11.0->hvplot) (2.0.2)
# Requirement already satisfied: mdit-py-plugins in c:\users\meetp\appdata\roaming\python\python39\site-packages (from panel>=0.11.0->hvplot) (0.4.0)
# Requirement already satisfied: requests in c:\users\meetp\appdata\roaming\python\python39\site-packages (from panel>=0.11.0->hvplot) (2.28.2)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from panel>=0.11.0->hvplot) (4.66.1)
# Requirement already satisfied: bleach in c:\users\meetp\appdata\roaming\python\python39\site-packages (from panel>=0.11.0->hvplot) (6.0.0)
# Requirement already satisfied: typing-extensions in c:\users\meetp\appdata\roaming\python\python39\site-packages (from panel>=0.11.0->hvplot) (4.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from Jinja2>=2.9->bokeh>=1.0.0->hvplot) (2.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.1->pandas->hvplot) (1.16.0)
# Requirement already satisfied: colorama in c:\users\meetp\appdata\roaming\python\python39\site-packages (from tqdm>=4.48.0->panel>=0.11.0->hvplot) (0.4.6)
# Requirement already satisfied: webencodings in c:\users\meetp\appdata\roaming\python\python39\site-packages (from bleach->panel>=0.11.0->hvplot) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\meetp\appdata\roaming\python\python39\site-packages (from linkify-it-py->panel>=0.11.0->hvplot) (1.0.2)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from markdown->panel>=0.11.0->hvplot) (6.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from markdown-it-py->panel>=0.11.0->hvplot) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python39\lib\site-packages (from requests->panel>=0.11.0->hvplot) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from requests->panel>=0.11.0->hvplot) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python39\lib\site-packages (from requests->panel>=0.11.0->hvplot) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from requests->panel>=0.11.0->hvplot) (2022.12.7)
# Requirement already satisfied: zipp>=0.5 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from importlib-metadata>=4.4->markdown->panel>=0.11.0->hvplot) (3.12.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: geoviews in c:\users\meetp\appdata\roaming\python\python39\site-packages (1.10.1)
# Requirement already satisfied: bokeh<3.3.0,>=3.1.0 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from geoviews) (3.2.2)
# Requirement already satisfied: cartopy>=0.18.0 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from geoviews) (0.22.0)
# Requirement already satisfied: holoviews>=1.16.0 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from geoviews) (1.17.1)
# Requirement already satisfied: packaging in c:\users\meetp\appdata\roaming\python\python39\site-packages (from geoviews) (23.1)
# Requirement already satisfied: numpy in c:\users\meetp\appdata\roaming\python\python39\site-packages (from geoviews) (1.23.5)
# Requirement already satisfied: shapely in c:\python39\lib\site-packages (from geoviews) (2.0.2)
# Requirement already satisfied: param in c:\users\meetp\appdata\roaming\python\python39\site-packages (from geoviews) (1.13.0)
# Requirement already satisfied: panel>=1.0.0 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from geoviews) (1.2.3)
# Requirement already satisfied: pyproj in c:\python39\lib\site-packages (from geoviews) (3.6.1)
# Requirement already satisfied: xyzservices in c:\python39\lib\site-packages (from geoviews) (2023.10.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (3.1.2)
# Requirement already satisfied: contourpy>=1 in c:\python39\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (1.0.7)
# Requirement already satisfied: pandas>=1.2 in c:\python39\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (1.5.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\python39\lib\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from bokeh<3.3.0,>=3.1.0->geoviews) (6.2)
# Requirement already satisfied: matplotlib>=3.4 in c:\python39\lib\site-packages (from cartopy>=0.18.0->geoviews) (3.7.0)
# Requirement already satisfied: pyshp>=2.1 in c:\python39\lib\site-packages (from cartopy>=0.18.0->geoviews) (2.3.1)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from holoviews>=1.16.0->geoviews) (3.0.0)
# Requirement already satisfied: colorcet in c:\users\meetp\appdata\roaming\python\python39\site-packages (from holoviews>=1.16.0->geoviews) (3.0.1)
# Requirement already satisfied: markdown in c:\users\meetp\appdata\roaming\python\python39\site-packages (from panel>=1.0.0->geoviews) (3.4.3)
# Requirement already satisfied: markdown-it-py in c:\users\meetp\appdata\roaming\python\python39\site-packages (from panel>=1.0.0->geoviews) (3.0.0)
# Requirement already satisfied: linkify-it-py in c:\users\meetp\appdata\roaming\python\python39\site-packages (from panel>=1.0.0->geoviews) (2.0.2)
# Requirement already satisfied: mdit-py-plugins in c:\users\meetp\appdata\roaming\python\python39\site-packages (from panel>=1.0.0->geoviews) (0.4.0)
# Requirement already satisfied: requests in c:\users\meetp\appdata\roaming\python\python39\site-packages (from panel>=1.0.0->geoviews) (2.28.2)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from panel>=1.0.0->geoviews) (4.66.1)
# Requirement already satisfied: bleach in c:\users\meetp\appdata\roaming\python\python39\site-packages (from panel>=1.0.0->geoviews) (6.0.0)
# Requirement already satisfied: typing-extensions in c:\users\meetp\appdata\roaming\python\python39\site-packages (from panel>=1.0.0->geoviews) (4.5.0)
# Requirement already satisfied: certifi in c:\users\meetp\appdata\roaming\python\python39\site-packages (from pyproj->geoviews) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from Jinja2>=2.9->bokeh<3.3.0,>=3.1.0->geoviews) (2.1.2)
# Requirement already satisfied: cycler>=0.10 in c:\python39\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python39\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python39\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python39\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\python39\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (5.12.0)
# Requirement already satisfied: pytz>=2020.1 in c:\python39\lib\site-packages (from pandas>=1.2->bokeh<3.3.0,>=3.1.0->geoviews) (2022.7.1)
# Requirement already satisfied: colorama in c:\users\meetp\appdata\roaming\python\python39\site-packages (from tqdm>=4.48.0->panel>=1.0.0->geoviews) (0.4.6)
# Requirement already satisfied: six>=1.9.0 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from bleach->panel>=1.0.0->geoviews) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\meetp\appdata\roaming\python\python39\site-packages (from bleach->panel>=1.0.0->geoviews) (0.5.1)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from colorcet->holoviews>=1.16.0->geoviews) (0.5.0)
# Requirement already satisfied: uc-micro-py in c:\users\meetp\appdata\roaming\python\python39\site-packages (from linkify-it-py->panel>=1.0.0->geoviews) (1.0.2)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from markdown->panel>=1.0.0->geoviews) (6.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from markdown-it-py->panel>=1.0.0->geoviews) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python39\lib\site-packages (from requests->panel>=1.0.0->geoviews) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from requests->panel>=1.0.0->geoviews) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python39\lib\site-packages (from requests->panel>=1.0.0->geoviews) (1.26.14)
# Requirement already satisfied: zipp>=0.5 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from importlib-metadata>=4.4->markdown->panel>=1.0.0->geoviews) (3.12.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: geopandas in c:\users\meetp\appdata\roaming\python\python39\site-packages (0.14.0)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from geopandas) (1.9.5)
# Requirement already satisfied: packaging in c:\users\meetp\appdata\roaming\python\python39\site-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.4.0 in c:\python39\lib\site-packages (from geopandas) (1.5.3)
# Requirement already satisfied: pyproj>=3.3.0 in c:\python39\lib\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in c:\python39\lib\site-packages (from geopandas) (2.0.2)
# Requirement already satisfied: attrs>=19.2.0 in c:\python39\lib\site-packages (from fiona>=1.8.21->geopandas) (22.2.0)
# Requirement already satisfied: certifi in c:\users\meetp\appdata\roaming\python\python39\site-packages (from fiona>=1.8.21->geopandas) (2022.12.7)
# Requirement already satisfied: click~=8.0 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from fiona>=1.8.21->geopandas) (8.1.3)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in c:\users\meetp\appdata\roaming\python\python39\site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: setuptools in c:\python39\lib\site-packages (from fiona>=1.8.21->geopandas) (56.0.0)
# Requirement already satisfied: importlib-metadata in c:\users\meetp\appdata\roaming\python\python39\site-packages (from fiona>=1.8.21->geopandas) (6.0.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python39\lib\site-packages (from pandas>=1.4.0->geopandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from pandas>=1.4.0->geopandas) (1.23.5)
# Requirement already satisfied: colorama in c:\users\meetp\appdata\roaming\python\python39\site-packages (from click~=8.0->fiona>=1.8.21->geopandas) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\meetp\appdata\roaming\python\python39\site-packages (from importlib-metadata->fiona>=1.8.21->geopandas) (3.12.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")
# Display sample data
city_data_df['Country'].fillna('Unknown', inplace=True)
city_data_df.dropna(subset=['Country'], inplace=True)

city_data_df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0        bethel  41.3712  -73.4140      9.70        88         100
# 1        1     carnarvon -24.8667  113.6333     32.78        27           0
# 2        2        barika  35.3890    5.3658     20.48        26           0
# 3        3  faya-largeau  17.9257   19.1043     29.36        23           6
# 4        4      smithers  54.7804 -127.1743     14.18        58          75
#
#    Wind Speed Country        Date
# 0        2.05      US  1697332943
# 1        4.20      AU  1697333541
# 2        2.71      DZ  1697333541
# 3        9.66      TD  1697332980
# 4        2.06      CA  1697333541

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
import geoviews as gv
import geoviews.feature as gf
import geopandas as gpd
gv.extension('bokeh')
# Include 'City' in the vdims to make it available on hover
colored_points = gv.Points(gdf, ['Lng', 'Lat'], vdims=['City', 'Humidity']).opts(
    width=1200,  # Increasing width
    height=1200,  # Increasing height
    size=10, 
    color='Humidity', cmap='viridis', tools=['hover']
)

plot_colored = gv.tile_sources.OSM() * colored_points
plot_colored
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
ideal_cities = city_data_df[
    (city_data_df['Max Temp'] > 21) & 
    (city_data_df['Max Temp'] < 27) & 
    (city_data_df['Wind Speed'] < 4.5) & 
    (city_data_df['Cloudiness'] == 0)
]

print(ideal_cities)
# Out:
#      City_ID                 City      Lat       Lng  Max Temp  Humidity  \
#
# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Step 1: Set up your parameters
radius = 10000  # 10,000 meters
YOUR_API_KEY = "23f26a67a49d4abda216d2f34d3d2ba3"  # Replace with your Geoapify API key

params = {
    "type": "accommodation",
    "limit": 1,
    "apiKey": YOUR_API_KEY
}

print("Starting hotel search")

for index, row in hotel_df.iterrows():
    lat = row['Lat']
    lng = row['Lng']
    
    # Filtering for places within the defined radius and biasing the search towards the city's location
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"

    # Constructing the base URL for Geoapify Places API
    base_url = "https://api.geoapify.com/v2/places"

    # Making the API request
    response = requests.get(base_url, params=params)
    
    # Parsing the response to JSON
    data = response.json()
    
    # Extracting the hotel name or handling the case where none is found
    try:
        hotel_df.loc[index, "Hotel Name"] = data["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display the resulting DataFrame
hotel_df.head()
# Out:
# Starting hotel search
# salinas - nearest hotel: The Traveler's Hotel
# clarence town - nearest hotel: Erringhi Hotel
# al khums - nearest hotel: عمارة المشرقي
# margaret river - nearest hotel: No hotel found
# darab - nearest hotel: محدوده هتل جهانگردی
# morena - nearest hotel: No hotel found
# ambagarh chauki - nearest hotel: No hotel found
# tura - nearest hotel: No hotel found
# baise city - nearest hotel: 梦之源大酒店
# satellite beach - nearest hotel: Radisson Suite Hotel Oceanfront
# isla vista - nearest hotel: The Club & Guest House
# brandon - nearest hotel: Brandon Motor Lodge
# saint-pierre - nearest hotel: Tropic Hotel
# donggang - nearest hotel: No hotel found
# palm coast - nearest hotel: Days Inn
# jiaojiang - nearest hotel: 台州远洲凤凰山庄
# darbhanga - nearest hotel: Lodge
# santiago del estero - nearest hotel: Nuevo Hotel Brístol
# butte - nearest hotel: No hotel found
# barstow heights - nearest hotel: Baymont by Wyndham Barstow Historic Route 66
# al kharijah - nearest hotel: Kharga Hotel
# tindouf - nearest hotel: محمد بوسبي
# shijiang - nearest hotel: No hotel found
# al muwayh - nearest hotel: فندق ومطعم الموية
# ji'an - nearest hotel: 华侨国际酒店
#                City Country      Lat       Lng  Humidity            Hotel Name
# 28          salinas      US  36.6777 -121.6555        80  The Traveler's Hotel
# 130   clarence town      AU -32.5833  151.7833        19        Erringhi Hotel
# 157        al khums      LY  32.6486   14.2619        68         عمارة المشرقي
# 168  margaret river      AU -33.9500  115.0667        45        No hotel found
# 177           darab      IR  28.7519   54.5444        37   محدوده هتل جهانگردی

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
import geoviews as gv
import geoviews.feature as gf
import geopandas as gpd
gv.extension('bokeh')
gdf_hotels = gpd.GeoDataFrame(hotel_df, geometry=gpd.points_from_xy(hotel_df.Lng, hotel_df.Lat))

colored_points = gv.Points(gdf_hotels, ['Lng', 'Lat'], 
                           vdims=['City', 'Country', 'Hotel Name', 'Humidity']).opts(
    width=1200,  
    height=1200,  
    size=10,
    color='Humidity', cmap='viridis', tools=['hover']
)

plot_colored = gv.tile_sources.OSM() * colored_points
plot_colored
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Country,Hotel Name,Humidity)
